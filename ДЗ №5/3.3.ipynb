# %% [markdown]
# **Задача A**

# %%
[i**2 for i in range(a, b + 1)]

# %% [markdown]
# **Задача B**

# %%
[[num * i for num in range(1, n + 1)] for i in range(1, n + 1)]

# %% [markdown]
# **Задача C**

# %%
[len(substr) for substr in sentence.split()]

# %% [markdown]
# **Задача D**

# %%
{num for num in numbers if num % 2 != 0}

# %% [markdown]
# **Задача E**

# %%
{el for el in numbers if el % el**0.5 == 0}

# %% [markdown]
# **Задача F**

# %%
{el: text.lower().count(el) for el in text.lower() if el.isalpha()}

# %% [markdown]
# **Задача G**

# %%
{num: [i for i in range(1, num + 1) if num % i == 0] for num in numbers}

# %% [markdown]
# **Задача H**

# %%
''.join(el[0].upper() for el in string.split())

# %% [markdown]
# **Задача I**

# %%
' - '.join(sorted([res_el for res_el in (set(str(num) for num in numbers))], key=lambda x: int(x)))

# %% [markdown]
# **Задача J**

# %%
''.join(ch[0] * ch[1] for ch in rle)
